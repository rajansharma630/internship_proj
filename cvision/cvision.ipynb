# %%
import cv2
print(cv2.__version__)
# Out:
# 5.0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
image=np.full((1600,1600,3), 250, dtype='uint8')
image[400:500,400:1000]=[51,153,255]
image[600:700,400:1000]=[0,128,0]
cv2.imshow('image',image)
cv2.imwrite('image.jpg',image)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
image=cv2.imread('demo.jpg')
print(type(image))
#image=cv2.resize(image,(100,100))
image=cv2.flip(image,0)
r,b,g=cv2.split(image)
cv2.imshow('image',b)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       1 image=cv2.imread('demo.jpg')
#       2 print(type(image))
#       3 #image=cv2.resize(image,(100,100))
#       4 image=cv2.flip(image,0)
# ----> 5 r,b,g=cv2.split(image)
#       6 cv2.imshow('image',b)
#       7 cv2.waitKey(5000)
#       8 cv2.destroyAllWindows()
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
plt.imshow(r, cmap='jet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.imshow(r, cmap='jet')
#
# NameError: name 'r' is not defined
