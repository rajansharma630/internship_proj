# %%
import math
from sklearn.feature_extraction.text import TfidfVectorizer

doc=['The cat set on the mat', 'The dog played in the park', 'Cats and dogs are great pets']
tfidf=TfidfVectorizer()
result=tfidf.fit_transform(doc)
print(result)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 16 stored elements and shape (3, 15)>
#   Coords	Values
#   (0, 14)	0.6053485081062917
#   (0, 2)	0.3979802707840827
#   (0, 13)	0.3979802707840827
#   (0, 9)	0.3979802707840827
#   (0, 8)	0.3979802707840827
#   (1, 14)	0.6053485081062917
#   (1, 4)	0.3979802707840827
#   (1, 12)	0.3979802707840827
#   (1, 7)	0.3979802707840827
#   (1, 10)	0.3979802707840827
#   (2, 3)	0.4082482904638631
#   (2, 0)	0.4082482904638631
#   (2, 5)	0.4082482904638631
#   (2, 1)	0.4082482904638631
#   (2, 6)	0.4082482904638631
#   (2, 11)	0.4082482904638631

# %%
from nltk.corpus import stopwords
text= " This is my AI ML internship practice session. Today is the 7th day of my internship "
stop_words=set(stopwords.words('english'))
word_tokens= word_tokenize(text)
filtered_sentence=[]
for w in word_tokens:
    if w not in stop_words:
        if w not in stop_words:
            filtered_sentence.append(w)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from nltk.corpus import stopwords
# ----> 2 import word_tokenizer
#       3 text= " This is my AI ML internship practice session. Today is the 7th day of my internship "
#       4 stop_words=set(stopwords.words('english'))
#       5 word_tokens= word_tokenize(text)
#
# ModuleNotFoundError: No module named 'word_tokenizer'

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rajan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rajan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language= 'english')
word = 'civilization'
stemmer.stem(word)
# Out:
# 'civil'

# %%
from nltk.stem import WordNetLemmatizer
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()
print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 from nltk.stem import WordNetLemmatizer
# ----> 2 porter = PorterStemmer()
#       3 lemmatizer = WordNetLemmatizer()
#       4 print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
#
# NameError: name 'PorterStemmer' is not defined

# %%
from nltk.corpus import stopwords

# %%
text= """ This is my AI ML internship practice session. Today is the 7th day of my internship """
stop_words=set(stopwords.words('english'))
word_tokens= word_tokenize(text)
filtered_sentence=[]
for w in word_tokens:
    if w not in stop_words:
        if w not in stop_words:
            filtered_sentence.append(w)

# %%
from nltk.stem import WordNetLemmatizer
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()
print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from nltk.stem import WordNetLemmatizer
# ----> 2 porter = PorterStemmer()
#       3 lemmatizer = WordNetLemmatizer()
#       4 print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
#
# NameError: name 'PorterStemmer' is not defined

# %%
from nltk.corpus import stopwords

# %%
text="""This is my AI ML internship practice session.Today is the 7th day of my internship"""
stop_words=set(stopwords.words('english'))
word_tokens=word_tokenize(text)
filtered_sentence=[]
for w in word_tokens:

    if w not in stop_words:
        if w not in stop_words:
            filtered_sentence.append(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 text="""This is my AI ML internship practice session.Today is the 7th day of my internship"""
#       2 stop_words=set(stopwords.words('english'))
# ----> 3 word_tokens=word_tokenize(text)
#       4 filtered_sentence=[]
#       5 for w in word_tokens:
#       6
#
# NameError: name 'word_tokenize' is not defined

# %%
nltk.download('stopwords')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nltk.download('stopwords')
#
# NameError: name 'nltk' is not defined

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer(language="english")
word="civilization"
stemmer.stem(word)
# Out:
# 'civil'

# %%
nltk.download('wordnet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nltk.download('wordnet')
#
# NameError: name 'nltk' is not defined

# %%
from nltk.stem import SnowballStemmer,LancasterStemmer
sentence="It is good to be a pythoner who is pythonly pythoning with python"
words=nltk.word_tokenize(sentence)
for word in words:
    lanc=LancasterStemmer()
    print(lanc.stem(word))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 from nltk.stem import SnowballStemmer,LancasterStemmer
#       2 sentence="It is good to be a pythoner who is pythonly pythoning with python"
# ----> 3 words=nltk.word_tokenize(sentence)
#       4 for word in words:
#       5     lanc=LancasterStemmer()
#       6     print(lanc.stem(word))
#
# NameError: name 'nltk' is not defined

# %%
from nltk.stem import WordNetLemmatizer,PorterStemmer
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()
print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File d:\Environments\env\Lib\site-packages\nltk\corpus\util.py:85, in LazyCorpusLoader.__load(self)
#      84 try:
# ---> 85     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86 except LookupError:
#
# File d:\Environments\env\Lib\site-packages\nltk\data.py:877, in find(resource_name, paths)
#     876 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 877 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'wordnet' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/wordnet.zip/wordnet/'
#
#   Searched in:
#     - 'C:\\Users\\rajan/nltk_data'
#     - 'd:\\Environments\\env\\nltk_data'
#     - 'd:\\Environments\\env\\share\\nltk_data'
#     - 'd:\\Environments\\env\\lib\\nltk_data'
#     - 'C:\\Users\\rajan\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[14], line 4
#       1 from nltk.stem import WordNetLemmatizer,PorterStemmer
#       2 porter = PorterStemmer()
#       3 lemmatizer = WordNetLemmatizer()
# ----> 4 print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
#
# File d:\Environments\env\Lib\site-packages\nltk\stem\wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)     83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File d:\Environments\env\Lib\site-packages\nltk\stem\wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)     37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File d:\Environments\env\Lib\site-packages\nltk\corpus\util.py:129, in LazyCorpusLoader.__getattr__(self, attr)
#     124 if attr.startswith("__") and attr.endswith("__"):
#     125     raise AttributeError(
#     126         f"{type(self).__name__} object has no attribute {attr!r}"
#     127     )
# --> 129 self.__load()
#     130 # This looks circular, but its not, since __load() changes our
#     131 # __class__ to something new:
#     132 return getattr(self, attr)
#
# File d:\Environments\env\Lib\site-packages\nltk\corpus\util.py:87, in LazyCorpusLoader.__load(self)
#      85             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86         except LookupError:
# ---> 87             raise e
#      89 # Load the corpus.
#      90 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File d:\Environments\env\Lib\site-packages\nltk\corpus\util.py:82, in LazyCorpusLoader.__load(self)
#      80 else:
#      81     try:
# ---> 82         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      83     except LookupError as e:
#      84         try:
#
# File d:\Environments\env\Lib\site-packages\nltk\data.py:877, in find(resource_name, paths)
#     875 sep = "*" * 70
#     876 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 877 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'wordnet' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/wordnet'
#
#   Searched in:
#     - 'C:\\Users\\rajan/nltk_data'
#     - 'd:\\Environments\\env\\nltk_data'
#     - 'd:\\Environments\\env\\share\\nltk_data'
#     - 'd:\\Environments\\env\\lib\\nltk_data'
#     - 'C:\\Users\\rajan\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rajan\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\rajan\AppData\Roaming\nltk_data...
# True
